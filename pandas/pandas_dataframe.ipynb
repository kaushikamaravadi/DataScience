# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
dframe = DataFrame(np.arange(12).reshape(4,3))

# %%
dframe
# Out:
#    0   1   2
# 0  0   1   2
# 1  3   4   5
# 2  6   7   8
# 3  9  10  11

# %%
# constructing dataframe from a dictionary
data = {'City':['SF','LA','NYC'],'Population':[837000,3880000,8400000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
colors = Series(["Blue","Red"],index=[4,1])
dframe['Color']=colors

# %%
colors
# Out:
# 4    Blue
# 1     Red
# dtype: object

# %%
got = pd.read_csv('/home/ubuntu/PycharmProjects/Transcend/conversion files/got.csv')

# %%
got
# Out:
#         id                                                url  \
# 0     4952  http://www.tvmaze.com/episodes/4952/game-of-th...
# 1     4953  http://www.tvmaze.com/episodes/4953/game-of-th...
# 2     4954  http://www.tvmaze.com/episodes/4954/game-of-th...
# 3     4955  http://www.tvmaze.com/episodes/4955/game-of-th...
# 4     4956  http://www.tvmaze.com/episodes/4956/game-of-th...
# 5     4957  http://www.tvmaze.com/episodes/4957/game-of-th...
# 6     4958  http://www.tvmaze.com/episodes/4958/game-of-th...
# 7     4959  http://www.tvmaze.com/episodes/4959/game-of-th...
# 8     4960  http://www.tvmaze.com/episodes/4960/game-of-th...
# 9     4961  http://www.tvmaze.com/episodes/4961/game-of-th...
# 10    4962  http://www.tvmaze.com/episodes/4962/game-of-th...
# 11    4963  http://www.tvmaze.com/episodes/4963/game-of-th...
# 12    4964  http://www.tvmaze.com/episodes/4964/game-of-th...
# 13    4965  http://www.tvmaze.com/episodes/4965/game-of-th...
# ...

# %%
got.columns
# Out:
# Index(['id', 'url', 'name', 'season', 'number', 'airdate', 'airtime',
#        'airstamp', 'runtime', 'summary'],
#       dtype='object')

# %%
got.id.head()
# Out:
# 0    4952
# 1    4953
# 2    4954
# 3    4955
# 4    4956
# Name: id, dtype: int64

# %%
got['url']
# Out:
# 0     http://www.tvmaze.com/episodes/4952/game-of-th...
# 1     http://www.tvmaze.com/episodes/4953/game-of-th...
# 2     http://www.tvmaze.com/episodes/4954/game-of-th...
# 3     http://www.tvmaze.com/episodes/4955/game-of-th...
# 4     http://www.tvmaze.com/episodes/4956/game-of-th...
# 5     http://www.tvmaze.com/episodes/4957/game-of-th...
# 6     http://www.tvmaze.com/episodes/4958/game-of-th...
# 7     http://www.tvmaze.com/episodes/4959/game-of-th...
# 8     http://www.tvmaze.com/episodes/4960/game-of-th...
# 9     http://www.tvmaze.com/episodes/4961/game-of-th...
# 10    http://www.tvmaze.com/episodes/4962/game-of-th...
# 11    http://www.tvmaze.com/episodes/4963/game-of-th...
# 12    http://www.tvmaze.com/episodes/4964/game-of-th...
# 13    http://www.tvmaze.com/episodes/4965/game-of-th...
# 14    http://www.tvmaze.com/episodes/4966/game-of-th...
# 15    http://www.tvmaze.com/episodes/4967/game-of-th...
# 16    http://www.tvmaze.com/episodes/4968/game-of-th...
# ...

# %%
got.tail()
# Out:
#         id                                                url  \
# 56  717449  http://www.tvmaze.com/episodes/717449/game-of-...
# 57  729573  http://www.tvmaze.com/episodes/729573/game-of-...
# 58  729574  http://www.tvmaze.com/episodes/729574/game-of-...
# 59  729575  http://www.tvmaze.com/episodes/729575/game-of-...
# 60  937256  http://www.tvmaze.com/episodes/937256/game-of-...
#
#                       name  season  number     airdate airtime  \
# 56          The Broken Man       6       7  2016-06-05   21:00
# 57                  No One       6       8  2016-06-12   21:00
# 58  Battle of the Bastards       6       9  2016-06-19   21:00
# 59     The Winds of Winter       6      10  2016-06-26   21:00
# 60                     TBA       7       1  2017-07-16   21:00
#
#                      airstamp  runtime  \
# 56  2016-06-05T21:00:00-04:00       60
# 57  2016-06-12T21:00:00-04:00       60
# 58  2016-06-19T21:00:00-04:00       60
# 59  2016-06-26T21:00:00-04:00       69
# ...

# %%
got.ix[3]
# Out:
# id                                                       4955
# url         http://www.tvmaze.com/episodes/4955/game-of-th...
# name                    Cripples, Bastards, and Broken Things
# season                                                      1
# number                                                      4
# airdate                                            2011-05-08
# airtime                                                 21:00
# airstamp                            2011-05-08T21:00:00-04:00
# runtime                                                    60
# summary     <p>Tyrion stops at Winterfell on his way home ...
# Name: 3, dtype: object

# %%
seasons = len(got.number)

# %%
seasons
# Out:
# 61

# %%
from numpy.random import randn
dframe = DataFrame(randn(25).reshape((5,5)),index=['A','B','D','E','F'],
columns=['col1','col2','col3','col4','col5'])

# %%
dframe2 = dframe.reindex(['A','B','C','D','E','F'])

# %%
dframe2
# Out:
#        col1      col2      col3      col4      col5
# A -1.203250 -0.527193  0.646514 -1.818907 -0.061849
# B  0.228696  1.443542 -0.114840  0.829900  0.381211
# C       NaN       NaN       NaN       NaN       NaN
# D  1.038095  0.993339  0.227696 -0.124586 -0.612187
# E -0.531144  0.002963 -0.745390 -1.151526 -1.204906
# F  0.102887 -0.975245 -0.286919  0.527011 -2.587972

# %%
dframe2.isnull()
# Out:
#     col1   col2   col3   col4   col5
# A  False  False  False  False  False
# B  False  False  False  False  False
# C   True   True   True   True   True
# D  False  False  False  False  False
# E  False  False  False  False  False
# F  False  False  False  False  False

# %%
dframe2['col1']
# Out:
# A   -1.203250
# B    0.228696
# C         NaN
# D    1.038095
# E   -0.531144
# F    0.102887
# Name: col1, dtype: float64

# %%
dframe2['col1']['C']
# Out:
# nan

# %%
dframe2['col2']['B']
# Out:
# 1.4435416029994779

# %%
dframe2 > 1
# Out:
#     col1   col2   col3   col4   col5
# A  False  False  False  False  False
# B  False   True  False  False  False
# C  False  False  False  False  False
# D   True  False  False  False  False
# E  False  False  False  False  False
# F  False  False  False  False  False

# %%
ser1 = Series([0,1,2],index=['A','B','C'])
ser2 = Series([3,4,5,6],index=list('ABCD'))

# %%
ser1+ser2
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    NaN
# dtype: float64

# %%
ser1.add(ser2,fill_value=0)
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    6.0
# dtype: float64

# %%
ser1+ser2
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    NaN
# dtype: float64

# %%
len(got['season'].value_counts())
# Out:
# 7

# %%
got.head()
# Out:
#      id                                                url  \
# 0  4952  http://www.tvmaze.com/episodes/4952/game-of-th...
# 1  4953  http://www.tvmaze.com/episodes/4953/game-of-th...
# 2  4954  http://www.tvmaze.com/episodes/4954/game-of-th...
# 3  4955  http://www.tvmaze.com/episodes/4955/game-of-th...
# 4  4956  http://www.tvmaze.com/episodes/4956/game-of-th...
#
#                                     name  season  number     airdate airtime  \
# 0                       Winter is Coming       1       1  2011-04-17   21:00
# 1                          The Kingsroad       1       2  2011-04-24   21:00
# 2                              Lord Snow       1       3  2011-05-01   21:00
# 3  Cripples, Bastards, and Broken Things       1       4  2011-05-08   21:00
# 4                  The Wolf and the Lion       1       5  2011-05-15   21:00
#
#                     airstamp  runtime  \
# 0  2011-04-17T21:00:00-04:00       60
# 1  2011-04-24T21:00:00-04:00       60
# ...
