# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import warnings
# %matplotlib inline
sns.set_style('white')
from pandas import Series, DataFrame
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("report.csv")

# %%
df
# Out:
#       report_year agency_code         agency_jurisdiction  population  \
# 0            1975     NM00101             Albuquerque, NM    286238.0
# 1            1975     TX22001               Arlington, TX    112478.0
# 2            1975     GAAPD00                 Atlanta, GA    490584.0
# 3            1975     CO00101                  Aurora, CO    116656.0
# 4            1975     TX22701                  Austin, TX    300400.0
# 5            1975     MD00301        Baltimore County, MD    642154.0
# 6            1975     MDBPD00               Baltimore, MD    864100.0
# 7            1975     MA01301                  Boston, MA    616120.0
# 8            1975     NY01401                 Buffalo, NY    422276.0
# 9            1975     NC06001               Charlotte, NC    262103.0
# 10           1975     ILCPD00                 Chicago, IL   3150000.0
# 11           1975     OHCIP00              Cincinnati, OH    433367.0
# ...

# %%
unclean = df[df.agency_jurisdiction == 'United States']
df=df[df.agency_jurisdiction != 'United States']

# %%
all_crimes=plt.figure(figsize=(10,22))
all_crimes = sns.barplot(df["violent_crimes"]+df["homicides"]+
                 df["rapes"]+df["assaults"]+df["robberies"],                 
                 y=df["agency_jurisdiction"],estimator=sum ,ci=0)
all_crimes.set_title('Total crimes in US during (1975-2015)')
all_crimes.set(xlabel='Total number of crimes', ylabel='City')
plt.show()

# %%
plt.figure(figsize=(18,4))
sns.barplot(df["report_year"], df["crimes_percapita"], palette="BuGn_d",)
plt.ylabel("Rate of crimes")
plt.title('Crimes rates in New York City in 1975-2015')
plt.xlabel("Report Year")

# %%
plt.figure(figsize=(18,4))
sns.barplot(df["report_year"], df["violent_crimes"], palette="RdBu_r")
plt.ylabel("Total crimes in USA")
plt.title('Crimes in USA in 1975-2015')
plt.xlabel("Report Year")
plt.show()

# %%
df.head()
# Out:
#    report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0         1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1         1975     TX22001       Arlington, TX    112478.0           278.0
# 2         1975     GAAPD00         Atlanta, GA    490584.0          8033.0
# 3         1975     CO00101          Aurora, CO    116656.0           611.0
# 4         1975     TX22701          Austin, TX    300400.0          1215.0
#
#    homicides  rapes  assaults  robberies  months_reported  crimes_percapita  \
# 0       30.0  181.0    1353.0      819.0             12.0            832.52
# 1        5.0   28.0     132.0      113.0             12.0            247.16
# 2      185.0  443.0    3518.0     3887.0             12.0           1637.44
# 3        7.0   44.0     389.0      171.0             12.0            523.76
# 4       33.0  190.0     463.0      529.0             12.0            404.46
#
# ...

# %%
df.fillna(value=0)
# Out:
#       report_year agency_code         agency_jurisdiction  population  \
# 0            1975     NM00101             Albuquerque, NM    286238.0
# 1            1975     TX22001               Arlington, TX    112478.0
# 2            1975     GAAPD00                 Atlanta, GA    490584.0
# 3            1975     CO00101                  Aurora, CO    116656.0
# 4            1975     TX22701                  Austin, TX    300400.0
# 5            1975     MD00301        Baltimore County, MD    642154.0
# 6            1975     MDBPD00               Baltimore, MD    864100.0
# 7            1975     MA01301                  Boston, MA    616120.0
# 8            1975     NY01401                 Buffalo, NY    422276.0
# 9            1975     NC06001               Charlotte, NC    262103.0
# 10           1975     ILCPD00                 Chicago, IL   3150000.0
# 11           1975     OHCIP00              Cincinnati, OH    433367.0
# ...

# %%
violent_crimes=df["violent_crimes"]
total_number_of_crimes=np.nansum(violent_crimes)

nyc = df[df.agency_jurisdiction == 'New York City, NY']
total_nyc=nyc['violent_crimes'].sum()
percent=total_nyc/total_number_of_crimes*100
percent
# Out:
# 17.309752386743373

# %%
df.head()
# Out:
#    report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0         1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1         1975     TX22001       Arlington, TX    112478.0           278.0
# 2         1975     GAAPD00         Atlanta, GA    490584.0          8033.0
# 3         1975     CO00101          Aurora, CO    116656.0           611.0
# 4         1975     TX22701          Austin, TX    300400.0          1215.0
#
#    homicides  rapes  assaults  robberies  months_reported  crimes_percapita  \
# 0       30.0  181.0    1353.0      819.0             12.0            832.52
# 1        5.0   28.0     132.0      113.0             12.0            247.16
# 2      185.0  443.0    3518.0     3887.0             12.0           1637.44
# 3        7.0   44.0     389.0      171.0             12.0            523.76
# 4       33.0  190.0     463.0      529.0             12.0            404.46
#
# ...

# %%
ol = df.pivot_table(index=['report_year','agency_jurisdiction'], aggfunc='mean')
