# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('white')

# %%
stack = pd.read_csv('stack_overflow.csv')

# %%
stack.head()
# Out:
#    Unnamed: 0 collector      country   un_subregion     so_region age_range  \
# 0        1888  Facebook  Afghanistan  Southern Asia  Central Asia     20-24
# 1        4637  Facebook  Afghanistan  Southern Asia  Central Asia     30-34
# 2       11164  Facebook  Afghanistan  Southern Asia  Central Asia       NaN
# 3       21378  Facebook  Afghanistan  Southern Asia  Central Asia       NaN
# 4       30280  Facebook  Afghanistan  Southern Asia  Central Asia      > 60
#
#    age_midpoint                  gender  \
# 0          22.0                    Male
# 1          32.0                    Male
# 2           NaN                     NaN
# 3           NaN                  Female
# 4          65.0  Prefer not to disclose
#
#                                  self_identification              occupation  \
# 0                                         Programmer                     NaN
# 1                    Developer; Engineer; Programmer  Mobile developer - iOS
# 2                                                NaN                     NaN
# 3                                           Engineer                  DevOps
# 4  Developer; Engineer; Programmer; Sr. Developer...                     NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#             important_sameend           important_newtech  \
# 0                         NaN                         NaN
# 1  This is somewhat important      This is very important
# 2                         NaN                         NaN
# 3     I don't care about this  This is somewhat important
# 4                         NaN                         NaN
#
#        important_buildnew  important_buildexisting  \
# 0                     NaN                      NaN
# 1  This is very important  I don't care about this
# 2                     NaN                      NaN
# 3  This is very important   This is very important
# 4                     NaN                      NaN
#
#           important_promotion    important_companymission  \
# 0                         NaN                         NaN
# 1  This is somewhat important  This is somewhat important
# 2                         NaN                         NaN
# 3     I don't care about this     I don't care about this
# 4                         NaN                         NaN
#
#              important_wfh         important_ownoffice  \
# 0                      NaN                         NaN
# 1  I don't care about this     I don't care about this
# 2                      NaN                         NaN
# 3   This is very important  This is somewhat important
# 4                      NaN                         NaN
#
#                                 developer_challenges  \
# 0                                                NaN
# 1  Unrealistic expectations; Interacting with non...
# 2                                                NaN
# 3  Corporate policies; Interacting with non-techn...
# 4                                                NaN
#
#                                   why_stack_overflow
# 0                                                NaN
# 1  To get help for my job; Because I can't do my ...
# 2                                                NaN
# 3   To get help for my job; Beacause I love to learn
# 4                                                NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Reputation

# %%
reputation = stack.rep_range.value_counts()
reputation.plot.bar(figsize=(10,10),width=0.4)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('rep_range',size=20)
plt.xlabel('Range',size=20)
plt.figtext(0.9,0.9,0.9)

# %% [markdown]
# ## Asking and answeing

# %% [markdown]
# ## Motivation

# %% [markdown]
# ## Visit Frequency

# %%
visitfrequency = stack.visit_frequency.value_counts()
visitfrequency.plot.bar(figsize=(10,10),width=0.4, stacked=True )
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('Range',size=30)
plt.xlabel('Visit_Frequency',size=30)
plt.figtext(0.9,0.9,0.9)
plt.suptitle('Visit Frequency',size=30)
addition = sum(visitfrequency)
percentage = round((visitfrequency * 100) / addition)
percentage
# Out:
# Multiple times a day                                                56.0
# Once a day                                                          22.0
# Once a week                                                         15.0
# Once a month                                                         3.0
# Very rarely                                                          3.0
# I have never been on Stack Overflow. I just love taking surveys.     1.0
# Name: visit_frequency, dtype: float64

# %% [markdown]
# ##### Over half of developers say they visit Stack Overflow multiple times a day, and 78% of developers tell us they visit Stack Overflow daily.

# %% [markdown]
# ## Developers who code are Happy Coders!

# %%
happy_coders=pd.crosstab(stack.job_satisfaction,stack.commit_frequency)
happy_coders["Multiple times a day"].plot.bar(figsize=(10,10),width=0.4)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.ylabel('Range',size=20)
plt.xlabel('Job Satisfaction',size=20)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Happy Coders',size=20)
happy_coders
# Out:
# commit_frequency                        A couple times a week  \
# job_satisfaction
# I don't have a job                                         50
# I hate my job                                             165
# I love my job                                            1844
# I'm neither satisfied nor dissatisfied                    795
# I'm somewhat dissatisfied with my job                     794
# I'm somewhat satisfied with my job                       2780
# Other (please specify)                                     62
#
# commit_frequency                        A few times a month  \
# job_satisfaction
# I don't have a job                                       24
# I hate my job                                            68
# I love my job                                           523
# I'm neither satisfied nor dissatisfied                  238
# I'm somewhat dissatisfied with my job                   284
# I'm somewhat satisfied with my job                      710
# Other (please specify)                                   22
#
# commit_frequency                        I don't "check-in or commit code", but I do put code into production somewhat frequently  \
# job_satisfaction
# I don't have a job                                                                     24
# I hate my job                                                                          42
# I love my job                                                                         437
# I'm neither satisfied nor dissatisfied                                                169
# I'm somewhat dissatisfied with my job                                                 187
# I'm somewhat satisfied with my job                                                    516
# Other (please specify)                                                                 25
#
# commit_frequency                        I never check-in or commit code  \
# job_satisfaction
# I don't have a job                                                   29
# I hate my job                                                        32
# I love my job                                                       235
# I'm neither satisfied nor dissatisfied                               99
# I'm somewhat dissatisfied with my job                               100
# I'm somewhat satisfied with my job                                  278
# Other (please specify)                                               12
#
# commit_frequency                        Multiple times a day  Once a day  \
# job_satisfaction
# I don't have a job                                        93          20
# I hate my job                                            424          71
# I love my job                                           8508        1345
# I'm neither satisfied nor dissatisfied                  2456         544
# I'm somewhat dissatisfied with my job                   2533         469
# I'm somewhat satisfied with my job                     10047        1698
# Other (please specify)                                   199          36
#
# commit_frequency                        Other (please specify)
# job_satisfaction
# I don't have a job                                           9
# I hate my job                                               17
# I love my job                                              127
# I'm neither satisfied nor dissatisfied                      39
# I'm somewhat dissatisfied with my job                       63
# I'm somewhat satisfied with my job                         140
# Other (please specify)                                      42

# %%
happy = pd.crosstab(stack.commit_frequency,stack.job_satisfaction)
happy['I love my job'].plot.bar(figsize=(10,10),width=0.4)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('Range',size=20)
plt.xlabel('Job Satisfaction',size=20)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Happy Coders',size=30)

# %% [markdown]
# ## Checking-in Code

# %%
checkin_code = stack.commit_frequency.value_counts()
checkin_code.plot.bar(figsize=(10,10),width=0.4)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('Range',size=20)
plt.xlabel('Commit Frequency',size=20)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Check-in Code',size=20)
addition = sum(checkin_code)
percentage = round((checkin_code * 100) / addition)
percentage
# Out:
# Multiple times a day                                                                        57.0
# A couple times a week                                                                       18.0
# Once a day                                                                                  11.0
# A few times a month                                                                          6.0
# I don't "check-in or commit code", but I do put code into production somewhat frequently     4.0
# I never check-in or commit code                                                              3.0
# Other (please specify)                                                                       1.0
# Name: commit_frequency, dtype: float64

# %% [markdown]
# 57% of developers tell us they check-in or commit code multiple times per day.

# %% [markdown]
# ## Remote Developers Love Their Jobs

# %%
remote_developers = pd.crosstab(stack.remote,stack.job_satisfaction)
remote_developers['I love my job'].plot.bar(figsize=(10,10),width=0.4)
remote_developer = stack.remote.value_counts()
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('Range',size=20)
plt.xlabel('Commit Frequency',size=20)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Check-in Code',size=20)
addition = sum(remote_developer)
percentage = round((remote_developer * 100) / addition)
percentage
# Out:
# I rarely work remotely    48.0
# Never                     22.0
# Part-time remote          18.0
# Full-time remote          12.0
# Name: remote, dtype: float64

# %% [markdown]
# ## Global Remote

# %%
remote_country = pd.crosstab(stack.remote,stack.country)
individual = remote_country['Argentina'].sum()
percentage = remote_country['Argentina']['Full-time remote']

# %% [markdown]
# ## Remote Developers are More Experienced

# %%
remote_experienced = pd.crosstab(stack.experience_range,stack.remote)
remote_experienced["Full-time remote"].plot.bar(figsize=(10,10),width=0.4)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('Range',size=20)
plt.xlabel('Experience range',size=20)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Remote Developers',size=20)
# addition = sum(remote_experienced)
# percentage = round((remote_experienced * 100) / addition)
# percentage

# %% [markdown]
# ## Remote

# %%
complete_remote = stack.remote.value_counts()
complete_remote.plot.bar(figsize=(8,8))
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.ylabel('Range',size=10)
plt.xlabel('Experience range',size=10)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Remote Developers',size=10)
addition = sum(complete_remote)
percentage = round((complete_remote * 100) / addition)
percentage
# Out:
# I rarely work remotely    48.0
# Never                     22.0
# Part-time remote          18.0
# Full-time remote          12.0
# Name: remote, dtype: float64

# %% [markdown]
# About 12% of developers work remote full-time. 30% work remote part-time or full-time.

# %% [markdown]
# ##  Teams And Women on teams

# %%
stack.women_on_team.value_counts()
# Out:
# 0                         15929
# 1                          9835
# 2                          5374
# 3                          2643
# I am not on a "team"       1596
# 4                          1384
# 5                           907
# I'm not sure                528
# 11+                         420
# 6                           403
# 7                           247
# 8                           176
# 10                          158
# Other (please specify)      150
# 9                            58
# Name: women_on_team, dtype: int64

# %% [markdown]
# ## Company Size

# %%
company_size = stack.company_size_range.value_counts()
company_size.plot.bar(figsize=(30,30),width=0.6,cmap='terrain')
plt.xticks(size = 70)
plt.yticks(size = 70)
plt.ylabel('Range',size=60)
plt.xlabel('Company-Size',size=60)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Company Size',size=70)
addition = sum(company_size)
percentage = round((company_size * 100) / addition)
percentage
# Out:
# 20-99 employees               22.0
# 100-499 employees             17.0
# 10,000+ employees             12.0
# 10-19 employees               10.0
# 1-4 employees                  9.0
# 1,000-4,999 employees          9.0
# 5-9 employees                  8.0
# 500-999 employees              6.0
# 5,000-9,999 employees          3.0
# I am not part of a company     3.0
# I am not sure                  2.0
# Other (please specify)         0.0
# Name: company_size_range, dtype: float64

# %% [markdown]
# ## Industry

# %%
industry = stack.industry.value_counts()
industry.plot.bar(figsize=(10,10),width=0.5,cmap='seismic')
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel('Range',size=20)
plt.xlabel('Industry',size=20)
# plt.figtext(0.9,0.9,0.9)
plt.suptitle('Industry',size=20)
addition = sum(industry)
percentage = round((industry * 100) / addition)
percentage
# Out:
# Software Products          22.0
# Other (please specify)      9.0
# Web Services                9.0
# Finance / Banking           8.0
# Consulting                  7.0
# Internet                    7.0
# Media / Advertising         5.0
# Healthcare                  4.0
# Education                   4.0
# Telecommunications          4.0
# Consumer Products           3.0
# Government                  3.0
# Manufacturing               3.0
# Retail                      3.0
# Gaming                      2.0
# Automotive                  2.0
# Defense                     1.0
# Foundation / Non-Profit     1.0
# Aerospace                   1.0
# I'm a student               1.0
# Not Currently Employed      0.0
# Name: industry, dtype: float64

# %%
job_industry = pd.crosstab(stack.industry,stack.job_satisfaction)
job_industry
# .plot.bar(figsize=(30,30),width=0.6)
# plt.xticks(size = 70)
# plt.yticks(size = 70)
# plt.ylabel('Range',size=60)
# plt.xlabel('Company-Size',size=60)
# # plt.figtext(0.9,0.9,0.9)
# plt.suptitle('Company Size',size=70)
# addition = sum(job_industry)
# percentage = round((job_industry * 100) / addition)
# percentage
# Out:
# job_satisfaction         I don't have a job  I hate my job  I love my job  \
# industry
# Aerospace                                 0             13            117
# Automotive                                1             16            224
# Consulting                                4             47            935
# Consumer Products                         1             31            424
# Defense                                   2             17            121
# Education                                 8             34            572
# Finance / Banking                         6             92            889
# Foundation / Non-Profit                   5              8            149
# Gaming                                   16             18            408
# Government                                2             40            325
# Healthcare                                2             45            562
# I'm a student                            60              8             98
# Internet                                 21             41           1022
# Manufacturing                             2             25            311
# Media / Advertising                       3             46            593
# Not Currently Employed                   79              1             42
# Other (please specify)                   14             68           1273
# Retail                                    0             38            284
# Software Products                        16            144           3158
# Telecommunications                        1             46            359
# Web Services                             21             54           1331
#
# job_satisfaction         I'm neither satisfied nor dissatisfied  \
# industry
# Aerospace                                                    43
# Automotive                                                  112
# Consulting                                                  330
# Consumer Products                                           150
# Defense                                                      41
# Education                                                   129
# Finance / Banking                                           436
# Foundation / Non-Profit                                      40
# Gaming                                                       73
# Government                                                  159
# Healthcare                                                  174
# I'm a student                                                24
# Internet                                                    284
# Manufacturing                                               121
# Media / Advertising                                         212
# Not Currently Employed                                        8
# Other (please specify)                                      376
# Retail                                                      119
# Software Products                                          1014
# Telecommunications                                          154
# Web Services                                                401
#
# job_satisfaction         I'm somewhat dissatisfied with my job  \
# industry
# Aerospace                                                   40
# Automotive                                                  87
# Consulting                                                 305
# Consumer Products                                          170
# Defense                                                     49
# Education                                                  182
# Finance / Banking                                          475
# Foundation / Non-Profit                                     35
# Gaming                                                      64
# Government                                                 163
# Healthcare                                                 212
# I'm a student                                               20
# Internet                                                   251
# Manufacturing                                              144
# Media / Advertising                                        257
# Not Currently Employed                                       8
# Other (please specify)                                     424
# Retail                                                     120
# Software Products                                          901
# Telecommunications                                         237
# Web Services                                               347
#
# job_satisfaction         I'm somewhat satisfied with my job  \
# industry
# Aerospace                                               180
# Automotive                                              349
# Consulting                                             1139
# Consumer Products                                       543
# Defense                                                 187
# Education                                               586
# Finance / Banking                                      1449
# Foundation / Non-Profit                                 171
# Gaming                                                  368
# Government                                              538
# Healthcare                                              738
# I'm a student                                            89
# Internet                                               1051
# Manufacturing                                           469
# Media / Advertising                                     857
# Not Currently Employed                                   20
# Other (please specify)                                 1532
# Retail                                                  450
# Software Products                                      3592
# Telecommunications                                      600
# Web Services                                           1425
#
# job_satisfaction         Other (please specify)
# industry
# Aerospace                                     2
# Automotive                                    9
# Consulting                                   22
# Consumer Products                             7
# Defense                                       1
# Education                                    18
# Finance / Banking                            32
# Foundation / Non-Profit                       5
# Gaming                                       15
# Government                                   12
# Healthcare                                   13
# I'm a student                                 9
# Internet                                     26
# Manufacturing                                14
# Media / Advertising                          12
# Not Currently Employed                       10
# Other (please specify)                       96
# Retail                                        9
# Software Products                            59
# Telecommunications                            7
# Web Services                                 34

# %% [markdown]
# ## Salary by Education

# %%
pd.crosstab(stack.education,stack.salary_range)['More than $200,000'].sort_values().tail()
# Out:
# education
# I'm self-taught; On-the-job training; B.S. in Computer Science (or related field)    33
# I'm self-taught; On-the-job training                                                 33
# Masters Degree in Computer Science (or related field)                                38
# B.S. in Computer Science (or related field)                                          55
# I'm self-taught                                                                      82
# Name: More than $200,000, dtype: int64

# %% [markdown]
# ## Salary by Gender

# %%
sns.jointplot(stack['salary_midpoint'],stack['age_midpoint'],kind='hex',color='seagreen')

# %%
stack.groupby(['gender','age_range'])[['salary_midpoint']].median()
# Out:
#                                                salary_midpoint
# gender                 age_range
# Female                 20-24                           15000.0
#                        25-29                           35000.0
#                        30-34                           55000.0
#                        35-39                           65000.0
#                        40-49                           85000.0
#                        50-59                           95000.0
#                        < 20                             5000.0
#                        > 60                           105000.0
#                        Prefer not to disclose          15000.0
# Male                   20-24                           15000.0
#                        25-29                           35000.0
#                        30-34                           55000.0
#                        35-39                           75000.0
#                        40-49                           85000.0
#                        50-59                          105000.0
#                        < 20                             5000.0
#                        > 60                            95000.0
#                        Prefer not to disclose          65000.0
# Other                  20-24                           25000.0
#                        25-29                           40000.0
#                        30-34                           70000.0
#                        35-39                           75000.0
#                        40-49                           95000.0
#                        50-59                           25000.0
#                        < 20                             5000.0
#                        > 60                           210000.0
#                        Prefer not to disclose         175000.0
# Prefer not to disclose 20-24                           25000.0
#                        25-29                           35000.0
#                        30-34                           55000.0
#                        35-39                           65000.0
#                        40-49                           75000.0
#                        50-59                          115000.0
#                        < 20                             5000.0
#                        > 60                            95000.0
#                        Prefer not to disclose          45000.0

# %%
sns.boxplot(x=stack.age_midpoint, y=stack.salary_midpoint, hue=stack.gender, data=stack, palette="Blues_d")
sns.despine(offset=10, trim=True)
